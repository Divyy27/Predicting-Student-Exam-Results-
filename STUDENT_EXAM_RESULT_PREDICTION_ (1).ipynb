# %% [markdown]
# # **Project Title: Predicting Student Exam Results **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('StudentData.csv')

# %% [markdown]
# Data Set include following title:
#
# * StudentID
# * AttendenceRate
# * StudyTime
# * FinalExamScore
# * Result (P/F)

# %%
df
# Out:
#     Unnamed: 0  StudentID  AttendenceRate  StudyTime  FinalExamScore  \
# 0          NaN          1              62         75              78
# 1          NaN          2              76         54              65
# 2          NaN          3              45         35              43
# 3          NaN          4              34         76              67
# 4          NaN          5              67         55              78
# 5          NaN          6              88         43              67
# 6          NaN          7              23         98              89
# 7          NaN          8              45         76              65
# 8          NaN          9              34         54              43
# 9          NaN         10              98         78              76
# 10         NaN         11              66         56              65
# 11         NaN         12              89         78              87
# 12         NaN         13              90         76              93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      0 non-null      float64
#  1   StudentID       30 non-null     int64
#  2   AttendenceRate  30 non-null     int64
#  3   StudyTime       30 non-null     int64
#  4   FinalExamScore  30 non-null     int64
#  5   Result (P/F)    30 non-null     int64
# dtypes: float64(1), int64(5)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#        Unnamed: 0  StudentID  AttendenceRate  StudyTime  FinalExamScore  \
# count         0.0  30.000000       30.000000  30.000000       30.000000
# mean          NaN  15.500000       59.300000  63.533333       74.233333
# std           NaN   8.803408       21.820822  19.063837       12.544221
# min           NaN   1.000000       21.000000  23.000000       43.000000
# 25%           NaN   8.250000       45.000000  54.000000       65.500000
# 50%           NaN  15.500000       63.000000  62.000000       76.000000
# 75%           NaN  22.750000       75.750000  76.750000       84.250000
# max           NaN  30.000000       98.000000  98.000000       96.000000
#
#        Result (P/F)
# count     30.000000
# mean       0.633333
# std        0.490133
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        30
# StudentID          0
# AttendenceRate     0
# StudyTime          0
# FinalExamScore     0
# Result (P/F)       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'StudentID', 'AttendenceRate', 'StudyTime',
#        'FinalExamScore', 'Result (P/F)'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Unnamed: 0  StudentID  AttendenceRate  StudyTime  FinalExamScore  \
# 0         True      False           False      False           False
# 1         True      False           False      False           False
# 2         True      False           False      False           False
# 3         True      False           False      False           False
# 4         True      False           False      False           False
# 5         True      False           False      False           False
# 6         True      False           False      False           False
# 7         True      False           False      False           False
# 8         True      False           False      False           False
# 9         True      False           False      False           False
# 10        True      False           False      False           False
# 11        True      False           False      False           False
# 12        True      False           False      False           False
# ...

# %%
df.shape
# Out:
# (30, 6)

# %%
df.size
# Out:
# 180

# %%
df.head()
# Out:
#    Unnamed: 0  StudentID  AttendenceRate  StudyTime  FinalExamScore  \
# 0         NaN          1              62         75              78
# 1         NaN          2              76         54              65
# 2         NaN          3              45         35              43
# 3         NaN          4              34         76              67
# 4         NaN          5              67         55              78
#
#    Result (P/F)
# 0             1
# 1             1
# 2             0
# 3             0
# 4             1

# %%
df.tail()
# Out:
#     Unnamed: 0  StudentID  AttendenceRate  StudyTime  FinalExamScore  \
# 25         NaN         26              66         87              88
# 26         NaN         27              33         97              78
# 27         NaN         28              65         54              69
# 28         NaN         29              44         87              67
# 29         NaN         30              45         67              77
#
#     Result (P/F)
# 25             1
# 26             1
# 27             1
# 28             1
# 29             1

# %%
df['Result (P/F)'].value_counts()
# Out:
# Result (P/F)
# 1    19
# 0    11
# Name: count, dtype: int64

# %%
df.iloc[:,4]
# Out:
# 0     78
# 1     65
# 2     43
# 3     67
# 4     78
# 5     67
# 6     89
# 7     65
# 8     43
# 9     76
# 10    65
# 11    87
# 12    93
# 13    76
# 14    65
# 15    82
# 16    65
# 17    85
# 18    75
# 19    65
# 20    74
# 21    87
# 22    77
# 23    96
# 24    85
# 25    88
# 26    78
# 27    69
# 28    67
# 29    77
# Name: FinalExamScore, dtype: int64

# %%
df.loc[:,'FinalExamScore']
# Out:
# 0     78
# 1     65
# 2     43
# 3     67
# 4     78
# 5     67
# 6     89
# 7     65
# 8     43
# 9     76
# 10    65
# 11    87
# 12    93
# 13    76
# 14    65
# 15    82
# 16    65
# 17    85
# 18    75
# 19    65
# 20    74
# 21    87
# 22    77
# 23    96
# 24    85
# 25    88
# 26    78
# 27    69
# 28    67
# 29    77
# Name: FinalExamScore, dtype: int64

# %% [markdown]
# **Visualization**

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('StudentData.csv')

x = data['StudentID']
y = data['FinalExamScore']

plt.bar(x, y)

plt.title("STUDENT DATA BAR GRAPH")

plt.ylabel('FinalExamScore')

plt.xlabel('ID')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('StudentData.csv')

x = data['FinalExamScore']

plt.hist(x)

plt.title("Student Data Histogram")

plt.ylabel('Score')

plt.xlabel('FinalExamScore')

plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Result (P/F)')

# %% [markdown]
# Feature droping :

# %%
x=df.drop('Result (P/F)',axis=1)
y=df['Result (P/F)']

# %%
print(df)
# Out:
#     Unnamed: 0  StudentID  AttendenceRate  StudyTime  FinalExamScore  \
# 0          NaN          1              62         75              78
# 1          NaN          2              76         54              65
# 2          NaN          3              45         35              43
# 3          NaN          4              34         76              67
# 4          NaN          5              67         55              78
# 5          NaN          6              88         43              67
# 6          NaN          7              23         98              89
# 7          NaN          8              45         76              65
# 8          NaN          9              34         54              43
# 9          NaN         10              98         78              76
# 10         NaN         11              66         56              65
# 11         NaN         12              89         78              87
# 12         NaN         13              90         76              93
# ...

# %%
print(df)
# Out:
#     StudentID  AttendenceRate  StudyTime  FinalExamScore  Result (P/F)
# 0           1              62         75              78             1
# 1           2              76         54              65             1
# 2           3              45         35              43             0
# 3           4              34         76              67             0
# 4           5              67         55              78             1
# 5           6              88         43              67             1
# 6           7              23         98              89             0
# 7           8              45         76              65             1
# 8           9              34         54              43             0
# 9          10              98         78              76             1
# 10         11              66         56              65             1
# 11         12              89         78              87             1
# ...

# %%
x=df.drop('Result (P/F)',axis=1)
y=df['Result (P/F)']

# %%
print(df)
# Out:
#     StudentID  AttendenceRate  StudyTime  FinalExamScore  Result (P/F)
# 0           1              62         75              78             1
# 1           2              76         54              65             1
# 2           3              45         35              43             0
# 3           4              34         76              67             0
# 4           5              67         55              78             1
# 5           6              88         43              67             1
# 6           7              23         98              89             0
# 7           8              45         76              65             1
# 8           9              34         54              43             0
# 9          10              98         78              76             1
# 10         11              66         56              65             1
# 11         12              89         78              87             1
# ...

# %%
print(x.shape)
print(y.shape)
# Out:
# (30, 4)
# (30,)

# %%
print(x.head())
print(y.head())
# Out:
#    StudentID  AttendenceRate  StudyTime  FinalExamScore
# 0          1              62         75              78
# 1          2              76         54              65
# 2          3              45         35              43
# 3          4              34         76              67
# 4          5              67         55              78
# 0    1
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Result (P/F), dtype: int64

# %% [markdown]
# Train-Test Splitting :

# %%
from sklearn.model_selection import train_test_split


train_x, test_x, train_y, test_y=train_test_split(x,y,test_size=0.2,random_state=42)


print(train_x.shape)
print(test_x.shape)
print(train_y.shape)
print(test_y.shape)
# Out:
# (24, 4)
# (6, 4)
# (24,)
# (6,)

# %% [markdown]
# Linear Regression : In this following steps are to be followed while creating.
# ~ Model Calling
# ~ Model Trainning
# ~ Model Predict
# ~ Evalution metrices

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


model_lr=LinearRegression()


model_lr.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
y_pred_train=model_lr.predict(train_x)
y_pred_test=model_lr.predict(test_x)

# %%
train_mse_lr=mean_squared_error(train_y,y_pred_train)
test_mse_lr=mean_squared_error(test_y,y_pred_test)
train_r2_lr=r2_score(train_y,y_pred_train)
test_r2_lr=r2_score(test_y,y_pred_test)

# %%
print('Train MSE:',train_mse_lr)
print('Test MSE:',test_mse_lr)
print('Train R2:',train_r2_lr)
print('Test R2:',test_r2_lr)
# Out:
# Train MSE: 0.18631536566323362
# Test MSE: 0.21445993301407243
# Train R2: 0.09817100317628091
# Test R2: 0.03493030143667408

# %% [markdown]
# **Logistic Regression**
#
# 1.Model Calling\
# 2.Model Trainning\
# 3.Model Predict\
# 4.Evalution metrices

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
model_lor=LogisticRegression(max_iter=2000)

# %%
model_lor.fit(train_x,train_y)
# Out:
# LogisticRegression(max_iter=2000)

# %%
y_pred_lor_train=model_lor.predict(train_x)
y_pred_lor_test=model_lor.predict(test_x)

# %%
# Training
train_accuracy_lor=accuracy_score(train_y,y_pred_lor_train)
train_precision_lor=precision_score(train_y,y_pred_lor_train)
train_recall_lor=recall_score(train_y,y_pred_lor_train)
train_f1_lor=f1_score(train_y,y_pred_lor_train)

print('Accuracy:',train_accuracy_lor)
print('Precision:',train_precision_lor)
print('Recall:',train_recall_lor)
print('F1 Score:',train_f1_lor)
# Out:
# Accuracy: 0.7916666666666666
# Precision: 0.8
# Recall: 0.9411764705882353
# F1 Score: 0.8648648648648649

# %%
# Testing
test_accuracy_lor=accuracy_score(test_y,y_pred_lor_test)
test_precision_lor=precision_score(test_y,y_pred_lor_test)
test_recall_lor=recall_score(test_y,y_pred_lor_test)
test_f1_lor=f1_score(test_y,y_pred_lor_test)

print('Accuracy:',test_accuracy_lor)
print('Precision:',test_precision_lor)
print('Recall:',test_recall_lor)
print('F1 Score:',test_f1_lor)
# Out:
# Accuracy: 0.5
# Precision: 0.4
# Recall: 1.0
# F1 Score: 0.5714285714285714

# %%
# Training Report
print(classification_report(train_y, y_pred_lor_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.43      0.55         7
#            1       0.80      0.94      0.86        17
#
#     accuracy                           0.79        24
#    macro avg       0.78      0.68      0.71        24
# weighted avg       0.79      0.79      0.77        24

# %%
# Test Report
print(classification_report(test_y, y_pred_lor_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.40         4
#            1       0.40      1.00      0.57         2
#
#     accuracy                           0.50         6
#    macro avg       0.70      0.62      0.49         6
# weighted avg       0.80      0.50      0.46         6

# %% [markdown]
# K-Means Clustering Algorithm:\
# Model calling\
# Cluster selection\
# Model training\
# Evalution Matrix

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
k=3
model_KMeans = KMeans(n_clusters=k, random_state=42)

# %%
columns_for_clustering = ['AttendenceRate', 'FinalExamScore']
df_for_clustering = df[columns_for_clustering]

# %%
model_KMeans.fit(df_for_clustering)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
cluster_labels = model_KMeans.labels_

cluster_centers = model_KMeans.cluster_centers_

# %%
plt.scatter(df_for_clustering['AttendenceRate'], df_for_clustering['FinalExamScore'], c=cluster_labels, cmap='viridis')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='x', s=200, c='red', label='Cluster Centers')
plt.xlabel('AttendenceRate')
plt.ylabel('FinalExamScore')
plt.title('K-Means Clustering')
plt.legend()
plt.show()

# %%
silhouette=silhouette_score(df_for_clustering,cluster_labels)
davies_bouldin=davies_bouldin_score(df_for_clustering,cluster_labels)

print('Silhouette Score:',silhouette)
print('Davies Bouldin Index:',davies_bouldin)
# Out:
# Silhouette Score: 0.3818599852133515
# Davies Bouldin Index: 0.821957130781097
